# %% [markdown]
# # Exploring Grand Averages
#
# This notebook provides a means to investigate the grand averages for the YAC study.
#
# Reseachers/students are not intended to make changes here.

# %%
import glob
import mne
import numpy as np
import re
import pandas as pd
from IPython.display import display
import matplotlib.pyplot as plt
import pandas as pd
mne.viz.set_browser_backend('qt')
# Out:
# Using qt as 2D backend.

# %%
# Dictionary keyed by condition; values are a list of averaged (mne.Evoked) subject waveforms.
conditions = ['VO21', 'VO22', 'VO23', 'combine']
relabel = {'VO21':'target', 'VO22':'nontarget', 'VO23':'standard', 'combine':'novel'}
averaging_dict = {k:[] for k in conditions}

# %%
p3_sites = ['E77', 'E67', 'E72', 'E61', 'E53', 'E86', 'E62', 'E78']
n2_sites = ['E12', 'E11', 'E19', 'E7', 'E6', 'E106', 'E112', 'E5', 'E4', 'E13']
channel_interest = [
    "E4", "E5", "E6", "E7", "E11", "E12", "E13",
    "E19", "E53", "E61", "E62", "E65", "E66", "E67",
    "E69", "E70", "E71", "E72", "E74", "E75", "E76",
    "E77", "E78", "E82", "E83", "E84", "E86", "E89",
    "E90", "E96", "E106", "E112"
]
all_subject_paths = sorted(glob.glob('derivatives/segmented/vo/*.fif'))
for sub in all_subject_paths:
    for condition in conditions:
        new_epoch = mne.read_epochs(sub).pick(channel_interest)
        averaging_dict[condition].append((re.findall(r'_(\d+)_', sub)[0], new_epoch[condition].average()))
# Out:
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1001_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 320 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1001_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 320 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1001_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 320 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1001_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 320 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1002_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 340 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1002_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 340 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1002_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 340 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1002_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 340 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1003_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 337 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1003_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 337 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1003_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 337 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1003_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 337 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1004_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 348 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1004_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 348 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1004_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 348 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1004_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 348 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1005_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 328 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1005_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 328 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1005_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 328 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1005_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 328 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1006_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 349 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1006_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 349 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1006_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 349 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1006_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 349 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1007_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 345 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1007_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 345 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1007_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 345 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1007_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 345 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1008_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 348 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1008_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 348 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1008_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 348 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1008_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 348 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1009_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 350 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1009_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 350 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1009_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 350 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1009_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 350 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1010_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 273 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1010_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 273 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1010_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 273 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1010_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 273 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1011_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 348 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1011_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 348 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1011_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 348 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1011_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 348 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1012_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 325 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1012_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 325 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1012_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 325 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1012_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 325 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1014_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 350 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1014_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 350 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1014_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 350 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1014_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 350 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1015_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 288 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1015_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 288 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1015_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 288 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1015_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 288 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1016_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 347 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1016_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 347 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1016_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 347 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1016_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 347 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1017_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 285 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1017_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 285 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1017_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 285 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1017_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 285 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1018_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 333 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1018_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 333 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1018_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 333 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1018_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 333 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1019_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 325 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1019_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 325 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1019_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 325 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1019_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 325 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1020_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 347 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1020_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 347 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1020_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 347 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1020_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 347 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1021_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 347 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1021_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 347 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1021_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 347 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1021_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 347 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1022_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 331 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1022_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 331 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1022_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 331 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1022_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 331 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1023_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 331 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1023_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 331 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1023_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 331 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1023_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 331 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1024_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 321 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1024_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 321 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1024_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 321 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1024_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 321 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1025_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 349 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1025_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 349 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1025_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 349 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1025_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 349 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1026_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 342 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1026_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 342 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1026_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 342 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1026_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 342 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1028_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 322 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1028_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 322 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1028_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 322 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1028_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 322 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1029_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 346 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1029_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 346 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1029_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 346 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1029_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 346 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1030_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 349 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1030_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 349 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1030_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 349 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1030_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 349 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1031_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 341 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1031_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 341 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1031_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 341 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1031_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 341 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1033_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 343 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1033_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 343 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1033_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 343 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1033_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 343 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1034_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 308 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1034_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 308 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1034_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 308 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1034_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 308 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1035_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 349 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1035_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 349 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1035_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 349 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1035_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 349 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1036_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 336 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1036_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 336 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1036_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 336 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1036_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 336 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1037_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 312 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1037_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 312 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1037_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 312 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1037_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 312 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1038_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 349 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1038_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 349 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1038_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 349 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1038_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 349 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1039_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 317 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1039_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 317 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1039_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 317 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1039_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 317 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1040_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 309 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1040_pylqcr_epo.fif ...
#     Found the data of interest:
# ...
#         0 CTF compensation matrices available
# Not setting metadata
# 349 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1077_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 348 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1077_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 348 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1077_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 348 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1077_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 348 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1078_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 332 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1078_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 332 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1078_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 332 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1078_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 332 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1079_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 322 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1079_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 322 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1079_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 322 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1079_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 322 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1080_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 343 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1080_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 343 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1080_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 343 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1080_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 343 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1081_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 347 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1081_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 347 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1081_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 347 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1081_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 347 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1082_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 346 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1082_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 346 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1082_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 346 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1082_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 346 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1084_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 349 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1084_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 349 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1084_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 349 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1084_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 349 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1085_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 348 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1085_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 348 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1085_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 348 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1085_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 348 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1086_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 337 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1086_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 337 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1086_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 337 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1086_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 337 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1087_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 337 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1087_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 337 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1087_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 337 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1087_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 337 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1088_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 343 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1088_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 343 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1088_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 343 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1088_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 343 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1091_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 281 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1091_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 281 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1091_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 281 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /media/tyler/PathstoneProject/PathstoneYAC/derivatives/segmented/vo/yac_1091_pylqcr_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...    1000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 281 matching events found
# No baseline correction applied
# 0 projection items activated

# %%
def condition_summary(condition_label):
    print('Working on: ', condition_label)
    grand_average = mne.grand_average([item[1] for item in averaging_dict[condition_label]])
    display(grand_average)
    grand_average.plot()
    times = np.arange(-0.1, .65, .1)
    fig = grand_average.plot_topomap(times=times, colorbar=True)
    fig.suptitle(condition_label)
for condition in conditions:
    condition_summary(condition)
# Out:
# Working on:  VO21
# Identifying common channels ...
# <Evoked | 'Grand average (n = 83)' (average, N=83), -0.2 – 1 s, baseline -0.2 – 0 s, 32 ch, ~240 kB>
# <MNEFigure size 1200x220 with 9 Axes>
# Working on:  VO22
# Identifying common channels ...
# <Evoked | 'Grand average (n = 83)' (average, N=83), -0.2 – 1 s, baseline -0.2 – 0 s, 32 ch, ~240 kB>
# <MNEFigure size 1200x220 with 9 Axes>
# Working on:  VO23
# Identifying common channels ...
# <Evoked | 'Grand average (n = 83)' (average, N=83), -0.2 – 1 s, baseline -0.2 – 0 s, 32 ch, ~240 kB>
# <MNEFigure size 1200x220 with 9 Axes>
# Working on:  combine
# Identifying common channels ...
# <Evoked | 'Grand average (n = 83)' (average, N=83), -0.2 – 1 s, baseline -0.2 – 0 s, 32 ch, ~240 kB>
# <MNEFigure size 1200x220 with 9 Axes>

# %%
mne.viz.plot_compare_evokeds({k:[t[1] for t in v] for k, v in averaging_dict.items()}, picks=['E71'])
mne.viz.plot_compare_evokeds({k:[t[1] for t in v] for k, v in averaging_dict.items()}, picks=['E6'])
# Out:
# [<Figure size 800x600 with 2 Axes>]
